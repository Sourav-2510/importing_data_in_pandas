# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-2510/intro_to_pandas/blob/main/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("Black_friday_sale.csv",index_col=0,header=0)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  102071.000000   102071.000000       102071.000000        70544.000000
# mean        8.086009        0.410724            5.263101            9.845912
# std         6.507869        0.491968            3.736337            5.109314
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        31065.000000
# mean            12.664285
# std              4.114492
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
df.median()
# Out:
# <ipython-input-9-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Occupation             7.0
# Marital_Status         0.0
# Product_Category_1     5.0
# Product_Category_2     9.0
# Product_Category_3    14.0
# dtype: float64

# %% [markdown]
# #dealing with empty cells

# %%
new_df=df.dropna()

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000011  P00053842      F  26-35         1.0             C
# 1000013  P00350442      M  46-50         1.0             C
# 1000013  P00155442      M  46-50         1.0             C
# 1000013   P0094542      M  46-50         1.0             C
# 1000015  P00161842      M  26-35         7.0             A
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000011                          1             0.0                 4.0
# 1000013                          3             1.0                 2.0
# 1000013                          3             1.0                 1.0
# 1000013                          3             1.0                 2.0
# 1000015                          1             0.0                10.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000011                 5.0                12.0
# 1000013                 3.0                15.0
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  102071.000000   102071.000000       102071.000000        70544.000000
# mean        8.086009        0.410724            5.263101            9.845912
# std         6.507869        0.491968            3.736337            5.109314
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        31065.000000
# mean            12.664285
# std              4.114492
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  31065.000000    31065.000000        31065.000000        31065.000000
# mean       8.203219        0.399742            2.710800            6.853823
# std        6.469291        0.489853            2.549648            4.509030
# min        0.000000        0.000000            1.000000            2.000000
# 25%        3.000000        0.000000            1.000000            2.000000
# 50%        7.000000        0.000000            1.000000            6.000000
# 75%       14.000000        1.000000            4.000000           10.000000
# max       20.000000        1.000000           15.000000           16.000000
#
#        Product_Category_3
# count        31065.000000
# mean            12.664285
# std              4.114492
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %% [markdown]
# ####the removal of empty cell may cause deletion of a lot of rows from the data sheet which is not good for data analysis.
# So replace the naN values with zeros

# %%
new_df1=df.fillna(0)

# %%
new_df1.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  102071.000000   102071.000000       102071.000000        70544.000000
# mean        8.086009        0.410724            5.263101            9.845912
# std         6.507869        0.491968            3.736337            5.109314
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        31065.000000
# mean            12.664285
# std              4.114492
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df1.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  102072.000000   102072.000000       102072.000000       102072.000000
# mean        8.085930        0.410720            5.263050            6.804706
# std         6.507887        0.491967            3.736355            6.223856
# min         0.000000        0.000000            0.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       102072.000000
# mean             3.854299
# std              6.253702
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              8.000000
# max             18.000000

# %% [markdown]
# #replacing the naN column with the mean/meadian/mode value

# %%
mean=df["Product_Category_3"].mean()

# %%
new_df1=df.fillna(mean)

# %%
mean
# Out:
# 12.664284564622566

# %%
new_df1.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0           12.664285
# 1000009                 5.0           12.664285
# ...

# %%
median=df["Product_Category_3"].median()

# %%
new_df1=df.fillna(median)

# %%
median
# Out:
# 14.0

# %%
new_df1.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                14.0
# 1000009                 5.0                14.0
# ...

# %%
mode=df["Product_Category_3"].mode()

# %%
mode
# Out:
# 0    16.0
# Name: Product_Category_3, dtype: float64

# %%
new_df2=df.fillna(int(mode))

# %%
new_df2.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                16.0
# 1000009                 5.0                16.0
# ...

# %% [markdown]
# #wrong data

# %%
import numpy as np

# %%
df["Product_Category_3"].replace(np.nan,0,inplace=True)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df["Product_Category_1"].replace(np.nan,0,inplace=True)

# %%
df["Product_Category_2"].replace(np.nan,0,inplace=True)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                         4+             1.0                 5.0
# 1000010                         4+             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df["Stay_In_Current_City_Years"].replace('4+','4',inplace=True)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50         7.0             B
# 1000009  P00113442      M  26-35        17.0             C
# 1000010  P00288442      F  36-45         1.0             B
# 1000010  P00145342      F  36-45         1.0             B
# 1000011  P00053842      F  26-35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                          4             1.0                 5.0
# 1000010                          4             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df["Age"].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17', nan],
#       dtype=object)

# %%
df["Age"].replace(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],['50','35','45','25','55','60','17'],inplace=True)

# %%
df.head()
# Out:
#         Product_ID Gender Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  50         7.0             B
# 1000009  P00113442      M  35        17.0             C
# 1000010  P00288442      F  45         1.0             B
# 1000010  P00145342      F  45         1.0             B
# 1000011  P00053842      F  35         1.0             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2             1.0                 1.0
# 1000009                          0             0.0                 3.0
# 1000010                          4             1.0                 5.0
# 1000010                          4             1.0                 4.0
# 1000011                          1             0.0                 4.0
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df["Age"].replace(np.nan,0,inplace=True)

# %%
df["Age"]=df["Age"].astype('int')

# %%
df["Stay_In_Current_City_Years"].replace(np.nan,0,inplace=True)

# %%
df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].astype('int')

# %%
print(df.dtypes)
# Out:
# Product_ID                     object
# Gender                         object
# Age                             int64
# Occupation                    float64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %% [markdown]
# #duplicates

# %%
df.drop_duplicates()
# Out:
#         Product_ID Gender  Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M   50         7.0             B
# 1000009  P00113442      M   35        17.0             C
# 1000010  P00288442      F   45         1.0             B
# 1000010  P00145342      F   45         1.0             B
# 1000011  P00053842      F   35         1.0             C
# ...            ...    ...  ...         ...           ...
# 1001285  P00102042      M   45         4.0             A
# 1001285  P00313442      M   45         4.0             A
# 1001285  P00181742      M   45         4.0             A
# 1001291  P00118042      F   45         0.0             A
# 1001295         P0    NaN    0         NaN           NaN
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                           2             1.0                 1.0
# 1000009                           0             0.0                 3.0
# ...

# %%
df.drop_duplicates(subset=["Product_Category_1"],keep='first',inplace=True,ignore_index=True)

# %%
df
# Out:
#    Product_ID Gender  Age  Occupation City_Category  \
# 0   P00128942      M   50         7.0             B
# 1   P00113442      M   35        17.0             C
# 2   P00288442      F   45         1.0             B
# 3   P00145342      F   45         1.0             B
# 4   P00350442      M   50         1.0             C
# 5   P00161842      M   35         7.0             A
# 6   P00121042      M   50         3.0             A
# 7   P00119242      F   45         3.0             A
# 8   P00113642      M   25         4.0             C
# 9   P00089042      M   50        18.0             C
# 10  P00148642      M   25         2.0             B
# 11  P00124342      F   45        20.0             B
# 12  P00331242      F   35         2.0             B
# 13  P00054342      M   50        13.0             B
# 14  P00355642      F   35        12.0             B
# 15  P00214842      M   45        16.0             B
# 16  P00174842      M   55         6.0             B
# ...

# %% [markdown]
# #correlation

# %%
df.corr()
# Out:
# <ipython-input-66-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                  Age  Occupation  Stay_In_Current_City_Years  \
# Age                         1.000000    0.190719                    0.281030
# Occupation                  0.190719    1.000000                   -0.096882
# Stay_In_Current_City_Years  0.281030   -0.096882                    1.000000
# Marital_Status              0.353553   -0.103572                    0.356348
# Product_Category_1          0.345870    0.164696                   -0.111433
# Product_Category_2          0.082009   -0.360149                    0.093943
# Product_Category_3         -0.125885   -0.320561                    0.125997
#
#                             Marital_Status  Product_Category_1  \
# ...
